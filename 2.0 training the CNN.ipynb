# %%
import numpy as np

data=np.load('data.npy')
target=np.load('target.npy')

#loading the save numpy arrays in the previous code

# %%
from keras.models import Sequential
from keras.layers import Dense,Activation,Flatten,Dropout
from keras.layers import Conv2D,MaxPooling2D
from keras.callbacks import ModelCheckpoint

model=Sequential()

model.add(Conv2D(200,(3,3),input_shape=data.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
#The first CNN layer followed by Relu and MaxPooling layers

model.add(Conv2D(100,(3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
#The second convolution layer followed by Relu and MaxPooling layers

model.add(Flatten())
model.add(Dropout(0.5))
#Flatten layer to stack the output convolutions from second convolution layer
model.add(Dense(50,activation='relu'))
#Dense layer of 64 neurons
model.add(Dense(2,activation='softmax'))
#The Final layer with two outputs for two categories

model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
from sklearn.model_selection import train_test_split

train_data,test_data,train_target,test_target=train_test_split(data,target,test_size=0.1)

# %%
checkpoint = ModelCheckpoint('model-{epoch:03d}.model',monitor='val_loss',verbose=0,save_best_only=True,mode='auto')
history=model.fit(train_data,train_target,epochs=20,callbacks=[checkpoint],validation_split=0.2)
# Out:
# Epoch 1/20
# 31/31 [==============================] - ETA: 0s - loss: 0.6775 - accuracy: 0.5677WARNING:tensorflow:From C:\Users\HP\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From C:\Users\HP\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: model-001.model\assets
# 31/31 [==============================] - 80s 3s/step - loss: 0.6775 - accuracy: 0.5677 - val_loss: 0.6012 - val_accuracy: 0.6573
# Epoch 2/20
# 31/31 [==============================] - ETA: 0s - loss: 0.4869 - accuracy: 0.7616INFO:tensorflow:Assets written to: model-002.model\assets
# 31/31 [==============================] - 74s 2s/step - loss: 0.4869 - accuracy: 0.7616 - val_loss: 0.3608 - val_accuracy: 0.8710
# Epoch 3/20
# 31/31 [==============================] - ETA: 0s - loss: 0.3216 - accuracy: 0.8717INFO:tensorflow:Assets written to: model-003.model\assets
# 31/31 [==============================] - 72s 2s/step - loss: 0.3216 - accuracy: 0.8717 - val_loss: 0.2653 - val_accuracy: 0.8871
# Epoch 4/20
# 31/31 [==============================] - ETA: 0s - loss: 0.2362 - accuracy: 0.9081INFO:tensorflow:Assets written to: model-004.model\assets
# 31/31 [==============================] - 72s 2s/step - loss: 0.2362 - accuracy: 0.9081 - val_loss: 0.2030 - val_accuracy: 0.9234
# Epoch 5/20
# 31/31 [==============================] - ETA: 0s - loss: 0.1519 - accuracy: 0.9414INFO:tensorflow:Assets written to: model-005.model\assets
# 31/31 [==============================] - 71s 2s/step - loss: 0.1519 - accuracy: 0.9414 - val_loss: 0.1966 - val_accuracy: 0.9435
# Epoch 6/20
# 31/31 [==============================] - 67s 2s/step - loss: 0.1279 - accuracy: 0.9556 - val_loss: 0.2067 - val_accuracy: 0.9435
# Epoch 7/20
# 31/31 [==============================] - ETA: 0s - loss: 0.0877 - accuracy: 0.9737INFO:tensorflow:Assets written to: model-007.model\assets
# 31/31 [==============================] - 67s 2s/step - loss: 0.0877 - accuracy: 0.9737 - val_loss: 0.1676 - val_accuracy: 0.9355
# Epoch 8/20
# 31/31 [==============================] - ETA: 0s - loss: 0.0740 - accuracy: 0.9788INFO:tensorflow:Assets written to: model-008.model\assets
# 31/31 [==============================] - 73s 2s/step - loss: 0.0740 - accuracy: 0.9788 - val_loss: 0.1585 - val_accuracy: 0.9556
# Epoch 9/20
# 31/31 [==============================] - 68s 2s/step - loss: 0.0545 - accuracy: 0.9848 - val_loss: 0.1671 - val_accuracy: 0.9395
# Epoch 10/20
# 31/31 [==============================] - 70s 2s/step - loss: 0.0566 - accuracy: 0.9778 - val_loss: 0.2186 - val_accuracy: 0.9234
# Epoch 11/20
# 31/31 [==============================] - 73s 2s/step - loss: 0.0684 - accuracy: 0.9747 - val_loss: 0.1698 - val_accuracy: 0.9395
# Epoch 12/20
# 31/31 [==============================] - 67s 2s/step - loss: 0.0443 - accuracy: 0.9848 - val_loss: 0.1891 - val_accuracy: 0.9435
# Epoch 13/20
# 31/31 [==============================] - 71s 2s/step - loss: 0.0292 - accuracy: 0.9859 - val_loss: 0.2110 - val_accuracy: 0.9435
# Epoch 14/20
# 31/31 [==============================] - ETA: 0s - loss: 0.0252 - accuracy: 0.9919INFO:tensorflow:Assets written to: model-014.model\assets
# 31/31 [==============================] - 71s 2s/step - loss: 0.0252 - accuracy: 0.9919 - val_loss: 0.1576 - val_accuracy: 0.9516
# Epoch 15/20
# 31/31 [==============================] - 61s 2s/step - loss: 0.0163 - accuracy: 0.9960 - val_loss: 0.3520 - val_accuracy: 0.9113
# Epoch 16/20
# 31/31 [==============================] - ETA: 0s - loss: 0.0861 - accuracy: 0.9707INFO:tensorflow:Assets written to: model-016.model\assets
# 31/31 [==============================] - 63s 2s/step - loss: 0.0861 - accuracy: 0.9707 - val_loss: 0.1481 - val_accuracy: 0.9516
# Epoch 17/20
# 31/31 [==============================] - 62s 2s/step - loss: 0.0282 - accuracy: 0.9919 - val_loss: 0.1703 - val_accuracy: 0.9516
# Epoch 18/20
# 31/31 [==============================] - 64s 2s/step - loss: 0.0223 - accuracy: 0.9929 - val_loss: 0.1677 - val_accuracy: 0.9556
# Epoch 19/20
# 31/31 [==============================] - 60s 2s/step - loss: 0.0141 - accuracy: 0.9970 - val_loss: 0.1761 - val_accuracy: 0.9556
# Epoch 20/20
# 31/31 [==============================] - 59s 2s/step - loss: 0.0173 - accuracy: 0.9949 - val_loss: 0.2040 - val_accuracy: 0.9435

# %%
from matplotlib import pyplot as plt

plt.plot(history.history['loss'],'r',label='training loss')
plt.plot(history.history['val_loss'],label='validation loss')
plt.xlabel('# epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
plt.plot(history.history['accuracy'],'r',label='training accuracy')
plt.plot(history.history['val_accuracy'],label='validation accuracy')
plt.xlabel('# epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
print(model.evaluate(test_data,test_target))
# Out:
# 5/5 [==============================] - 2s 344ms/step - loss: 0.1543 - accuracy: 0.9638
# [0.1542787104845047, 0.9637681245803833]
